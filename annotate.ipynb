# %%
import os
import glob
import cv2
from tqdm import tqdm

video_dir = "4DGS"
mp4_files = sorted(glob.glob(os.path.join(video_dir, "*.mp4")))

# %%
# export every frame of every .mp4 in "4DGS" into a dedicated directory per video
for vid_path in mp4_files:
    name = os.path.splitext(os.path.basename(vid_path))[0]
    frames_dir = os.path.join(video_dir, f"{name}_frames")
    os.makedirs(frames_dir, exist_ok=True)

    vid_cap = cv2.VideoCapture(vid_path)
    if not vid_cap.isOpened():
        print(f"Cannot open video: {vid_path}")
        continue

    total = int(vid_cap.get(cv2.CAP_PROP_FRAME_COUNT) or 0)
    pad = len(str(total)) if total > 0 else 6
    pbar = tqdm(total=total, desc=name)

    frame_i = 0
    while True:
        ret, frm = vid_cap.read()
        if not ret:
            break
        frame_i += 1
        out_path = os.path.join(frames_dir, f"{frame_i:0{pad}d}.jpg")
        # skip if already exists (useful to resume)
        if not os.path.exists(out_path):
            try:
                cv2.imwrite(out_path, frm, [int(cv2.IMWRITE_JPEG_QUALITY), 95])
            except Exception as e:
                print(f"Failed to write {out_path}: {e}")
        pbar.update(1)

    pbar.close()
    vid_cap.release()
    print(f"Saved frames for {name} -> {frames_dir}")
# Out:
# 001001: 100%|██████████| 60/60 [00:00<00:00, 61.92it/s]
# 001001: 100%|██████████| 60/60 [00:00<00:00, 61.92it/s]
# Saved frames for 001001 -> 4DGS/001001_frames
# 002001: 100%|██████████| 60/60 [00:00<00:00, 79.87it/s]
# Saved frames for 002001 -> 4DGS/002001_frames
# 003001: 100%|██████████| 60/60 [00:00<00:00, 74.44it/s]
# Saved frames for 003001 -> 4DGS/003001_frames
# 004001: 100%|██████████| 60/60 [00:00<00:00, 73.56it/s]
# Saved frames for 004001 -> 4DGS/004001_frames
# 005001: 100%|██████████| 60/60 [00:00<00:00, 76.91it/s]
# 005001: 100%|██████████| 60/60 [00:00<00:00, 76.91it/s]
# Saved frames for 005001 -> 4DGS/005001_frames
# 006001: 100%|██████████| 60/60 [00:00<00:00, 77.56it/s]
# Saved frames for 006001 -> 4DGS/006001_frames
# 008001: 100%|██████████| 60/60 [00:00<00:00, 77.89it/s]
# Saved frames for 008001 -> 4DGS/008001_frames
# 009001: 100%|██████████| 60/60 [00:00<00:00, 76.29it/s]
# Saved frames for 009001 -> 4DGS/009001_frames
# 010001: 100%|██████████| 60/60 [00:00<00:00, 78.14it/s]
# Saved frames for 010001 -> 4DGS/010001_frames
# 012001: 100%|██████████| 60/60 [00:00<00:00, 70.47it/s]
# Saved frames for 012001 -> 4DGS/012001_frames
# 101001: 100%|██████████| 60/60 [00:00<00:00, 81.07it/s]
# Saved frames for 101001 -> 4DGS/101001_frames
# 102001: 100%|██████████| 60/60 [00:00<00:00, 79.04it/s]
# Saved frames for 102001 -> 4DGS/102001_frames
# 103001: 100%|██████████| 60/60 [00:00<00:00, 81.14it/s]
# Saved frames for 103001 -> 4DGS/103001_frames
# 104001: 100%|██████████| 60/60 [00:00<00:00, 70.36it/s]
# Saved frames for 104001 -> 4DGS/104001_frames
# 105001: 100%|██████████| 60/60 [00:00<00:00, 79.48it/s]
# Saved frames for 105001 -> 4DGS/105001_frames
# 106001: 100%|██████████| 60/60 [00:00<00:00, 81.51it/s]
# Saved frames for 106001 -> 4DGS/106001_frames
# 107001: 100%|██████████| 60/60 [00:00<00:00, 80.74it/s]
# Saved frames for 107001 -> 4DGS/107001_frames
# 108001: 100%|██████████| 60/60 [00:00<00:00, 90.51it/s]
# Saved frames for 108001 -> 4DGS/108001_frames
# 109001: 100%|██████████| 60/60 [00:00<00:00, 75.76it/s]
# Saved frames for 109001 -> 4DGS/109001_frames
# 110001: 100%|██████████| 60/60 [00:00<00:00, 78.03it/s]
# Saved frames for 110001 -> 4DGS/110001_frames
# 111001: 100%|██████████| 60/60 [00:00<00:00, 72.07it/s]
# Saved frames for 111001 -> 4DGS/111001_frames
# 112001: 100%|██████████| 60/60 [00:00<00:00, 71.55it/s]
# Saved frames for 112001 -> 4DGS/112001_frames

# %%
from ultralytics.data.annotator import auto_annotate

videos = sorted(glob.glob(os.path.join(video_dir, "*_frames")))
for video_frames_dir in videos:
    auto_annotate(data=video_frames_dir, det_model="yolo11x.pt", sam_model="sam2_b.pt", 
                  output_dir=f"annotations/{os.path.basename(video_frames_dir)}", max_det=5)
# Out:
# image 1/60 /tmp2/b12902101/annotation/4DGS/001001_frames/01.jpg: 384x640 3 persons, 1 bench, 71.5ms
# image 1/60 /tmp2/b12902101/annotation/4DGS/001001_frames/01.jpg: 384x640 3 persons, 1 bench, 71.5ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/001001_frames/02.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.5ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/001001_frames/02.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.5ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/001001_frames/03.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/001001_frames/03.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/001001_frames/04.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/001001_frames/04.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/001001_frames/05.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/001001_frames/05.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/001001_frames/06.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/001001_frames/06.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/001001_frames/07.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.5ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/001001_frames/07.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.5ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/001001_frames/08.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/001001_frames/08.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/001001_frames/09.jpg: 384x640 3 persons, 1 bench, 1 skateboard, 13.7ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/001001_frames/09.jpg: 384x640 3 persons, 1 bench, 1 skateboard, 13.7ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/001001_frames/10.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/001001_frames/10.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/001001_frames/11.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/001001_frames/11.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/001001_frames/12.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/001001_frames/12.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/001001_frames/13.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/001001_frames/13.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/001001_frames/14.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/001001_frames/14.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/001001_frames/15.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/001001_frames/15.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/001001_frames/16.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/001001_frames/16.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/001001_frames/17.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/001001_frames/17.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/001001_frames/18.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/001001_frames/18.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/001001_frames/19.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/001001_frames/19.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/001001_frames/20.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.8ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/001001_frames/20.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.8ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/001001_frames/21.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/001001_frames/21.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/001001_frames/22.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/001001_frames/22.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/001001_frames/23.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/001001_frames/23.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/001001_frames/24.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/001001_frames/24.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/001001_frames/25.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/001001_frames/25.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/001001_frames/26.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.8ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/001001_frames/26.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.8ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/001001_frames/27.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/001001_frames/27.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/001001_frames/28.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/001001_frames/28.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/001001_frames/29.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/001001_frames/29.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/001001_frames/30.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.6ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/001001_frames/30.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.6ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/001001_frames/31.jpg: 384x640 3 persons, 1 bench, 14.1ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/001001_frames/31.jpg: 384x640 3 persons, 1 bench, 14.1ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/001001_frames/32.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/001001_frames/32.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/001001_frames/33.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.0ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/001001_frames/33.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.0ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/001001_frames/34.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/001001_frames/34.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/001001_frames/35.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/001001_frames/35.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/001001_frames/36.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/001001_frames/36.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/001001_frames/37.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/001001_frames/37.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/001001_frames/38.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/001001_frames/38.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/001001_frames/39.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.5ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/001001_frames/39.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.5ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/001001_frames/40.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/001001_frames/40.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/001001_frames/41.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/001001_frames/41.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/001001_frames/42.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/001001_frames/42.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/001001_frames/43.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/001001_frames/43.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/001001_frames/44.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/001001_frames/44.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/001001_frames/45.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/001001_frames/45.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/001001_frames/46.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/001001_frames/46.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/001001_frames/47.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/001001_frames/47.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/001001_frames/48.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/001001_frames/48.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/001001_frames/49.jpg: 384x640 3 persons, 1 bench, 17.0ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/001001_frames/49.jpg: 384x640 3 persons, 1 bench, 17.0ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/001001_frames/50.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/001001_frames/50.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/001001_frames/51.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/001001_frames/51.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/001001_frames/52.jpg: 384x640 3 persons, 1 bench, 13.5ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/001001_frames/52.jpg: 384x640 3 persons, 1 bench, 13.5ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/001001_frames/53.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/001001_frames/53.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/001001_frames/54.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/001001_frames/54.jpg: 384x640 3 persons, 1 bench, 13.6ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/001001_frames/55.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/001001_frames/55.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/001001_frames/56.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/001001_frames/56.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/001001_frames/57.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/001001_frames/57.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.6ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/001001_frames/58.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/001001_frames/58.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/001001_frames/59.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/001001_frames/59.jpg: 384x640 3 persons, 1 bench, 14.0ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/001001_frames/60.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/001001_frames/60.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# Speed: 2.5ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 2.5ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# image 1/60 /tmp2/b12902101/annotation/4DGS/002001_frames/01.jpg: 384x640 2 persons, 3 chairs, 15.0ms
# image 1/60 /tmp2/b12902101/annotation/4DGS/002001_frames/01.jpg: 384x640 2 persons, 3 chairs, 15.0ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/002001_frames/02.jpg: 384x640 2 persons, 3 chairs, 13.7ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/002001_frames/02.jpg: 384x640 2 persons, 3 chairs, 13.7ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/002001_frames/03.jpg: 384x640 2 persons, 3 chairs, 14.1ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/002001_frames/03.jpg: 384x640 2 persons, 3 chairs, 14.1ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/002001_frames/04.jpg: 384x640 2 persons, 3 chairs, 14.1ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/002001_frames/04.jpg: 384x640 2 persons, 3 chairs, 14.1ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/002001_frames/05.jpg: 384x640 2 persons, 2 chairs, 14.0ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/002001_frames/05.jpg: 384x640 2 persons, 2 chairs, 14.0ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/002001_frames/06.jpg: 384x640 2 persons, 2 chairs, 13.8ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/002001_frames/06.jpg: 384x640 2 persons, 2 chairs, 13.8ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/002001_frames/07.jpg: 384x640 2 persons, 1 cup, 2 chairs, 13.9ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/002001_frames/07.jpg: 384x640 2 persons, 1 cup, 2 chairs, 13.9ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/002001_frames/08.jpg: 384x640 2 persons, 1 cup, 2 chairs, 14.0ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/002001_frames/08.jpg: 384x640 2 persons, 1 cup, 2 chairs, 14.0ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/002001_frames/09.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/002001_frames/09.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/002001_frames/10.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/002001_frames/10.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/002001_frames/11.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/002001_frames/11.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/002001_frames/12.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/002001_frames/12.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/002001_frames/13.jpg: 384x640 3 persons, 2 chairs, 13.6ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/002001_frames/13.jpg: 384x640 3 persons, 2 chairs, 13.6ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/002001_frames/14.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/002001_frames/14.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/002001_frames/15.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/002001_frames/15.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/002001_frames/16.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/002001_frames/16.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/002001_frames/17.jpg: 384x640 3 persons, 2 chairs, 14.5ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/002001_frames/17.jpg: 384x640 3 persons, 2 chairs, 14.5ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/002001_frames/18.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/002001_frames/18.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/002001_frames/19.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/002001_frames/19.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/002001_frames/20.jpg: 384x640 3 persons, 2 chairs, 14.5ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/002001_frames/20.jpg: 384x640 3 persons, 2 chairs, 14.5ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/002001_frames/21.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/002001_frames/21.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/002001_frames/22.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/002001_frames/22.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/002001_frames/23.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/002001_frames/23.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/002001_frames/24.jpg: 384x640 3 persons, 2 chairs, 17.5ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/002001_frames/24.jpg: 384x640 3 persons, 2 chairs, 17.5ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/002001_frames/25.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/002001_frames/25.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/002001_frames/26.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/002001_frames/26.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/002001_frames/27.jpg: 384x640 3 persons, 2 chairs, 14.7ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/002001_frames/27.jpg: 384x640 3 persons, 2 chairs, 14.7ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/002001_frames/28.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/002001_frames/28.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/002001_frames/29.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/002001_frames/29.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/002001_frames/30.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/002001_frames/30.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/002001_frames/31.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/002001_frames/31.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/002001_frames/32.jpg: 384x640 3 persons, 1 umbrella, 1 chair, 14.5ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/002001_frames/32.jpg: 384x640 3 persons, 1 umbrella, 1 chair, 14.5ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/002001_frames/33.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/002001_frames/33.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/002001_frames/34.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/002001_frames/34.jpg: 384x640 3 persons, 2 chairs, 13.7ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/002001_frames/35.jpg: 384x640 3 persons, 2 chairs, 14.3ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/002001_frames/35.jpg: 384x640 3 persons, 2 chairs, 14.3ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/002001_frames/36.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/002001_frames/36.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/002001_frames/37.jpg: 384x640 3 persons, 2 chairs, 14.0ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/002001_frames/37.jpg: 384x640 3 persons, 2 chairs, 14.0ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/002001_frames/38.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/002001_frames/38.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/002001_frames/39.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/002001_frames/39.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/002001_frames/40.jpg: 384x640 3 persons, 2 chairs, 14.6ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/002001_frames/40.jpg: 384x640 3 persons, 2 chairs, 14.6ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/002001_frames/41.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/002001_frames/41.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/002001_frames/42.jpg: 384x640 3 persons, 2 chairs, 14.2ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/002001_frames/42.jpg: 384x640 3 persons, 2 chairs, 14.2ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/002001_frames/43.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/002001_frames/43.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/002001_frames/44.jpg: 384x640 3 persons, 2 chairs, 17.5ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/002001_frames/44.jpg: 384x640 3 persons, 2 chairs, 17.5ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/002001_frames/45.jpg: 384x640 3 persons, 2 chairs, 14.8ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/002001_frames/45.jpg: 384x640 3 persons, 2 chairs, 14.8ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/002001_frames/46.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/002001_frames/46.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/002001_frames/47.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/002001_frames/47.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/002001_frames/48.jpg: 384x640 3 persons, 2 chairs, 14.4ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/002001_frames/48.jpg: 384x640 3 persons, 2 chairs, 14.4ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/002001_frames/49.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/002001_frames/49.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/002001_frames/50.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/002001_frames/50.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/002001_frames/51.jpg: 384x640 3 persons, 2 chairs, 14.3ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/002001_frames/51.jpg: 384x640 3 persons, 2 chairs, 14.3ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/002001_frames/52.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/002001_frames/52.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/002001_frames/53.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/002001_frames/53.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/002001_frames/54.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/002001_frames/54.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/002001_frames/55.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/002001_frames/55.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/002001_frames/56.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/002001_frames/56.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/002001_frames/57.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/002001_frames/57.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/002001_frames/58.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/002001_frames/58.jpg: 384x640 3 persons, 2 chairs, 13.9ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/002001_frames/59.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/002001_frames/59.jpg: 384x640 3 persons, 2 chairs, 13.8ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/002001_frames/60.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/002001_frames/60.jpg: 384x640 3 persons, 2 chairs, 14.1ms
# Speed: 2.3ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 2.3ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# image 1/60 /tmp2/b12902101/annotation/4DGS/003001_frames/01.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.5ms
# image 1/60 /tmp2/b12902101/annotation/4DGS/003001_frames/01.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.5ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/003001_frames/02.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/003001_frames/02.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/003001_frames/03.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/003001_frames/03.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/003001_frames/04.jpg: 384x640 2 persons, 1 bench, 1 umbrella, 1 chair, 13.9ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/003001_frames/04.jpg: 384x640 2 persons, 1 bench, 1 umbrella, 1 chair, 13.9ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/003001_frames/05.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/003001_frames/05.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.7ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/003001_frames/06.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/003001_frames/06.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/003001_frames/07.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/003001_frames/07.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/003001_frames/08.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/003001_frames/08.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/003001_frames/09.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/003001_frames/09.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/003001_frames/10.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/003001_frames/10.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/003001_frames/11.jpg: 384x640 2 persons, 1 bench, 14.1ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/003001_frames/11.jpg: 384x640 2 persons, 1 bench, 14.1ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/003001_frames/12.jpg: 384x640 2 persons, 1 bench, 16.7ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/003001_frames/12.jpg: 384x640 2 persons, 1 bench, 16.7ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/003001_frames/13.jpg: 384x640 2 persons, 1 bench, 16.8ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/003001_frames/13.jpg: 384x640 2 persons, 1 bench, 16.8ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/003001_frames/14.jpg: 384x640 2 persons, 1 bench, 1 chair, 17.2ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/003001_frames/14.jpg: 384x640 2 persons, 1 bench, 1 chair, 17.2ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/003001_frames/15.jpg: 384x640 2 persons, 1 bench, 1 chair, 16.6ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/003001_frames/15.jpg: 384x640 2 persons, 1 bench, 1 chair, 16.6ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/003001_frames/16.jpg: 384x640 2 persons, 1 bench, 17.3ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/003001_frames/16.jpg: 384x640 2 persons, 1 bench, 17.3ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/003001_frames/17.jpg: 384x640 2 persons, 1 bench, 16.9ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/003001_frames/17.jpg: 384x640 2 persons, 1 bench, 16.9ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/003001_frames/18.jpg: 384x640 2 persons, 1 bench, 16.4ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/003001_frames/18.jpg: 384x640 2 persons, 1 bench, 16.4ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/003001_frames/19.jpg: 384x640 3 persons, 1 bench, 16.6ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/003001_frames/19.jpg: 384x640 3 persons, 1 bench, 16.6ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/003001_frames/20.jpg: 384x640 2 persons, 1 bench, 16.6ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/003001_frames/20.jpg: 384x640 2 persons, 1 bench, 16.6ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/003001_frames/21.jpg: 384x640 3 persons, 1 bench, 1 chair, 17.6ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/003001_frames/21.jpg: 384x640 3 persons, 1 bench, 1 chair, 17.6ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/003001_frames/22.jpg: 384x640 3 persons, 1 bench, 1 chair, 16.7ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/003001_frames/22.jpg: 384x640 3 persons, 1 bench, 1 chair, 16.7ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/003001_frames/23.jpg: 384x640 3 persons, 1 bench, 16.5ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/003001_frames/23.jpg: 384x640 3 persons, 1 bench, 16.5ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/003001_frames/24.jpg: 384x640 2 persons, 1 bench, 17.1ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/003001_frames/24.jpg: 384x640 2 persons, 1 bench, 17.1ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/003001_frames/25.jpg: 384x640 2 persons, 1 bench, 18.2ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/003001_frames/25.jpg: 384x640 2 persons, 1 bench, 18.2ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/003001_frames/26.jpg: 384x640 2 persons, 1 bench, 16.5ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/003001_frames/26.jpg: 384x640 2 persons, 1 bench, 16.5ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/003001_frames/27.jpg: 384x640 2 persons, 1 bench, 18.5ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/003001_frames/27.jpg: 384x640 2 persons, 1 bench, 18.5ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/003001_frames/28.jpg: 384x640 2 persons, 1 bench, 16.9ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/003001_frames/28.jpg: 384x640 2 persons, 1 bench, 16.9ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/003001_frames/29.jpg: 384x640 2 persons, 1 bench, 14.2ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/003001_frames/29.jpg: 384x640 2 persons, 1 bench, 14.2ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/003001_frames/30.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/003001_frames/30.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/003001_frames/31.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/003001_frames/31.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/003001_frames/32.jpg: 384x640 2 persons, 1 bench, 1 umbrella, 13.9ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/003001_frames/32.jpg: 384x640 2 persons, 1 bench, 1 umbrella, 13.9ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/003001_frames/33.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/003001_frames/33.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/003001_frames/34.jpg: 384x640 2 persons, 1 bench, 13.5ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/003001_frames/34.jpg: 384x640 2 persons, 1 bench, 13.5ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/003001_frames/35.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/003001_frames/35.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/003001_frames/36.jpg: 384x640 2 persons, 1 bench, 13.5ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/003001_frames/36.jpg: 384x640 2 persons, 1 bench, 13.5ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/003001_frames/37.jpg: 384x640 2 persons, 1 bench, 14.8ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/003001_frames/37.jpg: 384x640 2 persons, 1 bench, 14.8ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/003001_frames/38.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/003001_frames/38.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/003001_frames/39.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/003001_frames/39.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/003001_frames/40.jpg: 384x640 2 persons, 1 bench, 14.4ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/003001_frames/40.jpg: 384x640 2 persons, 1 bench, 14.4ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/003001_frames/41.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/003001_frames/41.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/003001_frames/42.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/003001_frames/42.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/003001_frames/43.jpg: 384x640 2 persons, 1 bench, 14.3ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/003001_frames/43.jpg: 384x640 2 persons, 1 bench, 14.3ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/003001_frames/44.jpg: 384x640 2 persons, 1 bench, 14.0ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/003001_frames/44.jpg: 384x640 2 persons, 1 bench, 14.0ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/003001_frames/45.jpg: 384x640 2 persons, 1 bench, 14.2ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/003001_frames/45.jpg: 384x640 2 persons, 1 bench, 14.2ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/003001_frames/46.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/003001_frames/46.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/003001_frames/47.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/003001_frames/47.jpg: 384x640 2 persons, 1 bench, 13.7ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/003001_frames/48.jpg: 384x640 2 persons, 1 bench, 14.0ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/003001_frames/48.jpg: 384x640 2 persons, 1 bench, 14.0ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/003001_frames/49.jpg: 384x640 2 persons, 1 bench, 14.6ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/003001_frames/49.jpg: 384x640 2 persons, 1 bench, 14.6ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/003001_frames/50.jpg: 384x640 2 persons, 1 bench, 13.3ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/003001_frames/50.jpg: 384x640 2 persons, 1 bench, 13.3ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/003001_frames/51.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/003001_frames/51.jpg: 384x640 2 persons, 1 bench, 13.8ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/003001_frames/52.jpg: 384x640 2 persons, 1 bench, 17.7ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/003001_frames/52.jpg: 384x640 2 persons, 1 bench, 17.7ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/003001_frames/53.jpg: 384x640 2 persons, 1 bench, 14.0ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/003001_frames/53.jpg: 384x640 2 persons, 1 bench, 14.0ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/003001_frames/54.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/003001_frames/54.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/003001_frames/55.jpg: 384x640 3 persons, 1 bench, 15.5ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/003001_frames/55.jpg: 384x640 3 persons, 1 bench, 15.5ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/003001_frames/56.jpg: 384x640 3 persons, 1 bench, 14.2ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/003001_frames/56.jpg: 384x640 3 persons, 1 bench, 14.2ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/003001_frames/57.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/003001_frames/57.jpg: 384x640 3 persons, 1 bench, 13.8ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/003001_frames/58.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/003001_frames/58.jpg: 384x640 3 persons, 1 bench, 13.9ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/003001_frames/59.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/003001_frames/59.jpg: 384x640 3 persons, 1 bench, 13.7ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/003001_frames/60.jpg: 384x640 3 persons, 1 bench, 14.3ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/003001_frames/60.jpg: 384x640 3 persons, 1 bench, 14.3ms
# Speed: 2.3ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 2.3ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# image 1/60 /tmp2/b12902101/annotation/4DGS/004001_frames/01.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 1/60 /tmp2/b12902101/annotation/4DGS/004001_frames/01.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/004001_frames/02.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/004001_frames/02.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/004001_frames/03.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.1ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/004001_frames/03.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.1ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/004001_frames/04.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.4ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/004001_frames/04.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.4ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/004001_frames/05.jpg: 384x640 2 persons, 1 bench, 1 chair, 15.3ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/004001_frames/05.jpg: 384x640 2 persons, 1 bench, 1 chair, 15.3ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/004001_frames/06.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.0ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/004001_frames/06.jpg: 384x640 3 persons, 1 bench, 1 chair, 14.0ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/004001_frames/07.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/004001_frames/07.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/004001_frames/08.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.0ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/004001_frames/08.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.0ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/004001_frames/09.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.0ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/004001_frames/09.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.0ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/004001_frames/10.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/004001_frames/10.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/004001_frames/11.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/004001_frames/11.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/004001_frames/12.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.1ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/004001_frames/12.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.1ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/004001_frames/13.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/004001_frames/13.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/004001_frames/14.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/004001_frames/14.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/004001_frames/15.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/004001_frames/15.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/004001_frames/16.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/004001_frames/16.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/004001_frames/17.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.0ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/004001_frames/17.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.0ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/004001_frames/18.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/004001_frames/18.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/004001_frames/19.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.7ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/004001_frames/19.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.7ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/004001_frames/20.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/004001_frames/20.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/004001_frames/21.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.4ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/004001_frames/21.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.4ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/004001_frames/22.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/004001_frames/22.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/004001_frames/23.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/004001_frames/23.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/004001_frames/24.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/004001_frames/24.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.3ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/004001_frames/25.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/004001_frames/25.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/004001_frames/26.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/004001_frames/26.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/004001_frames/27.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/004001_frames/27.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/004001_frames/28.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/004001_frames/28.jpg: 384x640 3 persons, 1 bench, 1 chair, 13.9ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/004001_frames/29.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.4ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/004001_frames/29.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.4ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/004001_frames/30.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.3ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/004001_frames/30.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.3ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/004001_frames/31.jpg: 384x640 1 person, 1 bench, 1 chair, 14.4ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/004001_frames/31.jpg: 384x640 1 person, 1 bench, 1 chair, 14.4ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/004001_frames/32.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.1ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/004001_frames/32.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.1ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/004001_frames/33.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/004001_frames/33.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/004001_frames/34.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/004001_frames/34.jpg: 384x640 2 persons, 1 bench, 1 chair, 14.2ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/004001_frames/35.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/004001_frames/35.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/004001_frames/36.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/004001_frames/36.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.8ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/004001_frames/37.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/004001_frames/37.jpg: 384x640 2 persons, 1 bench, 1 chair, 13.9ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/004001_frames/38.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/004001_frames/38.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/004001_frames/39.jpg: 384x640 1 person, 1 bench, 1 chair, 14.3ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/004001_frames/39.jpg: 384x640 1 person, 1 bench, 1 chair, 14.3ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/004001_frames/40.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/004001_frames/40.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/004001_frames/41.jpg: 384x640 1 person, 1 bench, 1 chair, 14.2ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/004001_frames/41.jpg: 384x640 1 person, 1 bench, 1 chair, 14.2ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/004001_frames/42.jpg: 384x640 1 person, 1 bench, 1 chair, 14.0ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/004001_frames/42.jpg: 384x640 1 person, 1 bench, 1 chair, 14.0ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/004001_frames/43.jpg: 384x640 1 person, 1 bench, 1 chair, 14.5ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/004001_frames/43.jpg: 384x640 1 person, 1 bench, 1 chair, 14.5ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/004001_frames/44.jpg: 384x640 1 person, 1 bench, 1 chair, 13.8ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/004001_frames/44.jpg: 384x640 1 person, 1 bench, 1 chair, 13.8ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/004001_frames/45.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/004001_frames/45.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/004001_frames/46.jpg: 384x640 1 person, 1 bench, 1 chair, 14.1ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/004001_frames/46.jpg: 384x640 1 person, 1 bench, 1 chair, 14.1ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/004001_frames/47.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/004001_frames/47.jpg: 384x640 1 person, 1 bench, 1 chair, 13.9ms
# ...
# image 47/60 /tmp2/b12902101/annotation/4DGS/111001_frames/47.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.7ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/111001_frames/48.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.9ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/111001_frames/48.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.9ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/111001_frames/49.jpg: 384x640 3 persons, 1 bench, 1 tie, 14.3ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/111001_frames/49.jpg: 384x640 3 persons, 1 bench, 1 tie, 14.3ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/111001_frames/50.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.9ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/111001_frames/50.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.9ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/111001_frames/51.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.7ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/111001_frames/51.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.7ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/111001_frames/52.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.7ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/111001_frames/52.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.7ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/111001_frames/53.jpg: 384x640 3 persons, 2 benchs, 14.2ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/111001_frames/53.jpg: 384x640 3 persons, 2 benchs, 14.2ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/111001_frames/54.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/111001_frames/54.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/111001_frames/55.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.9ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/111001_frames/55.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.9ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/111001_frames/56.jpg: 384x640 3 persons, 1 bench, 1 tie, 14.0ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/111001_frames/56.jpg: 384x640 3 persons, 1 bench, 1 tie, 14.0ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/111001_frames/57.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/111001_frames/57.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/111001_frames/58.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/111001_frames/58.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/111001_frames/59.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/111001_frames/59.jpg: 384x640 3 persons, 1 bench, 1 tie, 13.8ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/111001_frames/60.jpg: 384x640 3 persons, 1 bench, 1 tie, 15.6ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/111001_frames/60.jpg: 384x640 3 persons, 1 bench, 1 tie, 15.6ms
# Speed: 2.5ms preprocess, 14.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 2.5ms preprocess, 14.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# image 1/60 /tmp2/b12902101/annotation/4DGS/112001_frames/01.jpg: 384x640 3 persons, 1 tie, 14.5ms
# image 1/60 /tmp2/b12902101/annotation/4DGS/112001_frames/01.jpg: 384x640 3 persons, 1 tie, 14.5ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/112001_frames/02.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 2/60 /tmp2/b12902101/annotation/4DGS/112001_frames/02.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/112001_frames/03.jpg: 384x640 3 persons, 1 tie, 14.6ms
# image 3/60 /tmp2/b12902101/annotation/4DGS/112001_frames/03.jpg: 384x640 3 persons, 1 tie, 14.6ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/112001_frames/04.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 4/60 /tmp2/b12902101/annotation/4DGS/112001_frames/04.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/112001_frames/05.jpg: 384x640 3 persons, 1 tie, 14.3ms
# image 5/60 /tmp2/b12902101/annotation/4DGS/112001_frames/05.jpg: 384x640 3 persons, 1 tie, 14.3ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/112001_frames/06.jpg: 384x640 3 persons, 1 tie, 14.0ms
# image 6/60 /tmp2/b12902101/annotation/4DGS/112001_frames/06.jpg: 384x640 3 persons, 1 tie, 14.0ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/112001_frames/07.jpg: 384x640 3 persons, 1 tie, 14.1ms
# image 7/60 /tmp2/b12902101/annotation/4DGS/112001_frames/07.jpg: 384x640 3 persons, 1 tie, 14.1ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/112001_frames/08.jpg: 384x640 3 persons, 1 tie, 13.8ms
# image 8/60 /tmp2/b12902101/annotation/4DGS/112001_frames/08.jpg: 384x640 3 persons, 1 tie, 13.8ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/112001_frames/09.jpg: 384x640 3 persons, 1 tie, 13.9ms
# image 9/60 /tmp2/b12902101/annotation/4DGS/112001_frames/09.jpg: 384x640 3 persons, 1 tie, 13.9ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/112001_frames/10.jpg: 384x640 3 persons, 1 tie, 14.0ms
# image 10/60 /tmp2/b12902101/annotation/4DGS/112001_frames/10.jpg: 384x640 3 persons, 1 tie, 14.0ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/112001_frames/11.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 11/60 /tmp2/b12902101/annotation/4DGS/112001_frames/11.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/112001_frames/12.jpg: 384x640 3 persons, 1 tie, 14.1ms
# image 12/60 /tmp2/b12902101/annotation/4DGS/112001_frames/12.jpg: 384x640 3 persons, 1 tie, 14.1ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/112001_frames/13.jpg: 384x640 2 persons, 1 tie, 13.9ms
# image 13/60 /tmp2/b12902101/annotation/4DGS/112001_frames/13.jpg: 384x640 2 persons, 1 tie, 13.9ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/112001_frames/14.jpg: 384x640 3 persons, 1 tie, 13.9ms
# image 14/60 /tmp2/b12902101/annotation/4DGS/112001_frames/14.jpg: 384x640 3 persons, 1 tie, 13.9ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/112001_frames/15.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 15/60 /tmp2/b12902101/annotation/4DGS/112001_frames/15.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/112001_frames/16.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 16/60 /tmp2/b12902101/annotation/4DGS/112001_frames/16.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/112001_frames/17.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 17/60 /tmp2/b12902101/annotation/4DGS/112001_frames/17.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/112001_frames/18.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 18/60 /tmp2/b12902101/annotation/4DGS/112001_frames/18.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/112001_frames/19.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 19/60 /tmp2/b12902101/annotation/4DGS/112001_frames/19.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/112001_frames/20.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 20/60 /tmp2/b12902101/annotation/4DGS/112001_frames/20.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/112001_frames/21.jpg: 384x640 4 persons, 1 tie, 13.9ms
# image 21/60 /tmp2/b12902101/annotation/4DGS/112001_frames/21.jpg: 384x640 4 persons, 1 tie, 13.9ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/112001_frames/22.jpg: 384x640 3 persons, 1 tie, 14.7ms
# image 22/60 /tmp2/b12902101/annotation/4DGS/112001_frames/22.jpg: 384x640 3 persons, 1 tie, 14.7ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/112001_frames/23.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 23/60 /tmp2/b12902101/annotation/4DGS/112001_frames/23.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/112001_frames/24.jpg: 384x640 3 persons, 1 tie, 14.2ms
# image 24/60 /tmp2/b12902101/annotation/4DGS/112001_frames/24.jpg: 384x640 3 persons, 1 tie, 14.2ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/112001_frames/25.jpg: 384x640 4 persons, 1 tie, 13.8ms
# image 25/60 /tmp2/b12902101/annotation/4DGS/112001_frames/25.jpg: 384x640 4 persons, 1 tie, 13.8ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/112001_frames/26.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 26/60 /tmp2/b12902101/annotation/4DGS/112001_frames/26.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/112001_frames/27.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 27/60 /tmp2/b12902101/annotation/4DGS/112001_frames/27.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/112001_frames/28.jpg: 384x640 3 persons, 1 tie, 14.0ms
# image 28/60 /tmp2/b12902101/annotation/4DGS/112001_frames/28.jpg: 384x640 3 persons, 1 tie, 14.0ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/112001_frames/29.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 29/60 /tmp2/b12902101/annotation/4DGS/112001_frames/29.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/112001_frames/30.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 30/60 /tmp2/b12902101/annotation/4DGS/112001_frames/30.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/112001_frames/31.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 31/60 /tmp2/b12902101/annotation/4DGS/112001_frames/31.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/112001_frames/32.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 32/60 /tmp2/b12902101/annotation/4DGS/112001_frames/32.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/112001_frames/33.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.3ms
# image 33/60 /tmp2/b12902101/annotation/4DGS/112001_frames/33.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.3ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/112001_frames/34.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 34/60 /tmp2/b12902101/annotation/4DGS/112001_frames/34.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/112001_frames/35.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 35/60 /tmp2/b12902101/annotation/4DGS/112001_frames/35.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/112001_frames/36.jpg: 384x640 2 persons, 1 tie, 2 chairs, 14.0ms
# image 36/60 /tmp2/b12902101/annotation/4DGS/112001_frames/36.jpg: 384x640 2 persons, 1 tie, 2 chairs, 14.0ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/112001_frames/37.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 37/60 /tmp2/b12902101/annotation/4DGS/112001_frames/37.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/112001_frames/38.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 38/60 /tmp2/b12902101/annotation/4DGS/112001_frames/38.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/112001_frames/39.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.4ms
# image 39/60 /tmp2/b12902101/annotation/4DGS/112001_frames/39.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.4ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/112001_frames/40.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 40/60 /tmp2/b12902101/annotation/4DGS/112001_frames/40.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/112001_frames/41.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 41/60 /tmp2/b12902101/annotation/4DGS/112001_frames/41.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/112001_frames/42.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 42/60 /tmp2/b12902101/annotation/4DGS/112001_frames/42.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/112001_frames/43.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 43/60 /tmp2/b12902101/annotation/4DGS/112001_frames/43.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/112001_frames/44.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 44/60 /tmp2/b12902101/annotation/4DGS/112001_frames/44.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/112001_frames/45.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.4ms
# image 45/60 /tmp2/b12902101/annotation/4DGS/112001_frames/45.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.4ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/112001_frames/46.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 46/60 /tmp2/b12902101/annotation/4DGS/112001_frames/46.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/112001_frames/47.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 47/60 /tmp2/b12902101/annotation/4DGS/112001_frames/47.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/112001_frames/48.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 48/60 /tmp2/b12902101/annotation/4DGS/112001_frames/48.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/112001_frames/49.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 49/60 /tmp2/b12902101/annotation/4DGS/112001_frames/49.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/112001_frames/50.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 50/60 /tmp2/b12902101/annotation/4DGS/112001_frames/50.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.9ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/112001_frames/51.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 51/60 /tmp2/b12902101/annotation/4DGS/112001_frames/51.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/112001_frames/52.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.3ms
# image 52/60 /tmp2/b12902101/annotation/4DGS/112001_frames/52.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.3ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/112001_frames/53.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 53/60 /tmp2/b12902101/annotation/4DGS/112001_frames/53.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/112001_frames/54.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 54/60 /tmp2/b12902101/annotation/4DGS/112001_frames/54.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.2ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/112001_frames/55.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 55/60 /tmp2/b12902101/annotation/4DGS/112001_frames/55.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/112001_frames/56.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 56/60 /tmp2/b12902101/annotation/4DGS/112001_frames/56.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.0ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/112001_frames/57.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 57/60 /tmp2/b12902101/annotation/4DGS/112001_frames/57.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/112001_frames/58.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 58/60 /tmp2/b12902101/annotation/4DGS/112001_frames/58.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/112001_frames/59.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 59/60 /tmp2/b12902101/annotation/4DGS/112001_frames/59.jpg: 384x640 3 persons, 1 tie, 1 chair, 14.1ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/112001_frames/60.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# image 60/60 /tmp2/b12902101/annotation/4DGS/112001_frames/60.jpg: 384x640 3 persons, 1 tie, 1 chair, 13.8ms
# Speed: 2.4ms preprocess, 14.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Speed: 2.4ms preprocess, 14.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os
import glob
import json
import cv2
import numpy as np
from tqdm import tqdm

def find_ann_for_stem(stem, ann_dir):
    # 支援 .txt (annotations) 與 .json，回傳第一個匹配檔案路徑或 None
    for ext in ('.json', '.txt'):
        p = os.path.join(ann_dir, stem + ext)
        if os.path.exists(p):
            return p
    lst = glob.glob(os.path.join(ann_dir, stem + '.*'))
    return lst[0] if lst else None

def is_number(s):
    try:
        float(s)
        return True
    except:
        return False

def parse_txt(path, img_w, img_h):
    items = []
    with open(path, 'r') as f:
        for ln in f.readlines():
            parts = ln.strip().split()
            if not parts:
                continue
            # 若第一個 token 不是數字， treat as label
            if not is_number(parts[0]):
                label = parts[0]
                tokens = parts[1:]
            else:
                label = int(float(parts[0])) if len(parts)>0 else 0
                tokens = parts[1:]
            nums = [float(t) for t in tokens if is_number(t)]
            if len(nums) == 4 and len(tokens)==4:
                # 可能為 absolute bbox x y w h
                x, y, w_box, h_box = nums
                items.append((label, (int(x), int(y), int(x + w_box), int(y + h_box))))
            elif len(nums) == 5 and len(tokens)==5:
                # YOLO center-format (class handled above) -> xc yc w h (normalized)
                # tokens may be xc yc w h (class already consumed) or class xc yc w h if first was numeric
                xc, yc, w_box, h_box = nums[1:] if len(parts)>5 else nums[0:4]
                x1 = int((xc - w_box/2) * img_w)
                y1 = int((yc - h_box/2) * img_h)
                x2 = int((xc + w_box/2) * img_w)
                y2 = int((yc + h_box/2) * img_h)
                items.append((label, (x1, y1, x2, y2)))
            elif len(nums) >= 6 and len(nums) % 2 == 0:
                # polygon: decide normalized or absolute
                vals = nums
                maxv = max(vals)
                pts = []
                if maxv <= 1.0001:
                    # normalized coords
                    for i in range(0, len(vals), 2):
                        x = int(vals[i] * img_w)
                        y = int(vals[i+1] * img_h)
                        pts.append((x, y))
                else:
                    for i in range(0, len(vals), 2):
                        pts.append((int(vals[i]), int(vals[i+1])))
                items.append((label, pts))
            else:
                # 無法解析的行，跳過
                continue
    return items

def parse_json(path):
    items = []
    with open(path, 'r') as f:
        try:
            data = json.load(f)
        except Exception:
            return items
    ann_list = None
    if isinstance(data, dict):
        ann_list = data.get('annotations') or data.get('shapes') or data.get('objects') or data.get('labels')
        if ann_list is None and 'images' in data and 'annotations' in data:
            ann_list = data['annotations']
    elif isinstance(data, list):
        ann_list = data
    if not ann_list:
        return items
    for ann in ann_list:
        if not isinstance(ann, dict):
            continue
        if 'bbox' in ann and isinstance(ann['bbox'], (list, tuple)) and len(ann['bbox']) >= 4:
            x, y, w_box, h_box = ann['bbox'][:4]
            items.append((int(ann.get('category_id', ann.get('class', 0))), (int(x), int(y), int(x + w_box), int(y + h_box))))
        elif 'points' in ann and isinstance(ann['points'], list):
            pts = [(int(p[0]), int(p[1])) for p in ann['points']]
            items.append((int(ann.get('category_id', ann.get('class', 0))), pts))
        elif 'segmentation' in ann and isinstance(ann['segmentation'], list) and len(ann['segmentation'])>0:
            flat = ann['segmentation'][0]
            coords = [(int(flat[i]), int(flat[i+1])) for i in range(0, len(flat), 2)]
            items.append((int(ann.get('category_id', ann.get('class', 0))), coords))
    return items

# %%
# 對每個 frames 目錄產生對應輸出影片，輸出放在 output_videos/
os.makedirs('output_videos', exist_ok=True)

frames_dirs = sorted(glob.glob(os.path.join('4DGS', '*_frames')))
if not frames_dirs:
    print('No frames directories found under 4DGS/*_frames')

for frames_dir in frames_dirs:
    base = os.path.basename(frames_dir)
    ann_dir = os.path.join('annotations', base)
    out_video = os.path.join('output_videos', f'annotated_{base}.mp4')

    frame_paths = sorted(glob.glob(os.path.join(frames_dir, '*')))
    if not frame_paths:
        print(f'No frames in {frames_dir}, skip')
        continue

    # 嘗試從對應原始影片取得 fps（原始影片預期為 4DGS/{name}.mp4）
    name = base.replace('_frames','')
    orig_video = os.path.join('4DGS', f'{name}.mp4')
    fps = 30.0
    if os.path.exists(orig_video):
        cap = cv2.VideoCapture(orig_video)
        if cap.isOpened():
            fps = cap.get(cv2.CAP_PROP_FPS) or fps
        cap.release()

    first = cv2.imread(frame_paths[0])
    h, w = first.shape[:2]
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(out_video, fourcc, float(fps), (w, h))

    pbar = tqdm(total=len(frame_paths), desc=f'Annotating {base}')
    for fp in frame_paths:
        img = cv2.imread(fp)
        stem = os.path.splitext(os.path.basename(fp))[0]
        annp = find_ann_for_stem(stem, ann_dir)
        if annp:
            ext = os.path.splitext(annp)[1].lower()
            try:
                if ext == '.txt':
                    items = parse_txt(annp, w, h)
                elif ext == '.json':
                    items = parse_json(annp)
                else:
                    items = []
                # 繪製標註（bbox 與 polygon），polygon 先以 #00FFFF 填充（BGR=(255,255,0)）並 alpha 混合
                for cls, shape in items:
                    if isinstance(shape, tuple) and len(shape) == 4:
                        x1, y1, x2, y2 = shape
                        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                        cv2.putText(img, str(cls), (max(0, x1), max(0, y1-6)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 1, cv2.LINE_AA)
                    elif isinstance(shape, list) and len(shape) >= 2:
                        pts_arr = np.array(shape, dtype=np.int32).reshape((-1,1,2))
                        if len(shape) >= 3:
                            overlay = img.copy()
                            cv2.fillPoly(overlay, [pts_arr], color=(255,255,0))
                            alpha = 0.4
                            cv2.addWeighted(overlay, alpha, img, 1 - alpha, 0, img)
                        cv2.polylines(img, [pts_arr], isClosed=(len(shape) >= 3), color=(0,0,255), thickness=2)
                        x0, y0 = int(shape[0][0]), int(shape[0][1])
                        cv2.putText(img, str(cls), (x0, max(0, y0-6)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1, cv2.LINE_AA)
            except Exception as e:
                print(f"Failed to parse/draw {annp}: {e}")
        out.write(img)
        pbar.update(1)
    pbar.close()
    out.release()
    print(f'Wrote annotated video: {out_video}')
